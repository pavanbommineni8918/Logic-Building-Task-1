# %% [markdown]
# 1.User Login Check

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Sucessful")
else:
    print("Invalid Credentials")

# %% [markdown]
# 2.Pass/Fail Analyzer

# %%
marks = [45,78,90,33,60]
pass_count = 0
fail_count = 0

for m in marks:
  if m >= 50:
    pass_count += 1
  else:
    fail_count += 1

  print("Total Students:",len(marks))
  print("Passed Students:",pass_count)
  print("Failed Students:",fail_count)
# Out:
# Total Students: 5
# Passed Students: 0
# Failed Students: 1
# Total Students: 5
# Passed Students: 1
# Failed Students: 1
# Total Students: 5
# Passed Students: 2
# Failed Students: 1
# Total Students: 5
# Passed Students: 2
# Failed Students: 2
# Total Students: 5
# Passed Students: 3
# Failed Students: 2

# %% [markdown]
# 3. Simple Data Cleaner

# %%
names = [ " Alice ","bob","CHARLIE "]
cleaned_names = [name.strip().lower() for name in names]
print(cleaned_names)
# Out:
# ['alice', 'bob', 'charlie']

# %% [markdown]
# 4. Message Length Analyzer

# %%
message = ["HI", "Welcome to the platform", "OK"]
for m in message:
           print(m, "->", len(m), "| Long" if len(m) > 10 else "| Short")
# Out:
# HI -> 2 | Short
# Welcome to the platform -> 23 | Long
# OK -> 2 | Short

# %% [markdown]
# 5.Error Message Detector

# %%
logs = ["INFO","ERROR","WARNING","ERROR"]
print("Total ERROR entries:",logs.count("ERROR"))
# Out:
# Total ERROR entries: 2
